# %%
import pandas as pd
import math

# %%
df = pd.read_csv("cleaned_data.csv")

# %%
df
# Out:
#                                    BCR              BirdName  \
# 0                     Northern Rockies            House Wren
# 1    Southern Rockies/Colorado Plateau        Warbling Vireo
# 2    Southern Rockies/Colorado Plateau         Hermit Thrush
# 3           Boreal Hardwood Transition     Swainson's Thrush
# 4                             Piedmont  Yellow-breasted Chat
# ..                                 ...                   ...
# 508        Northern Pacific Rainforest       Dark-eyed Junco
# 509                   Northern Rockies    Western Wood-Pewee
# 510           Atlantic Northern Forest     American Redstart
# 511                 Coastal California      Bullock's Oriole
# 512                        Great Basin  Brown-headed Cowbird
#
#       BirdScientificName  BirdCount
# 0      Troglodytes aedon        910
# 1           Vireo gilvus       1204
# 2      Catharus guttatus        238
# 3     Catharus ustulatus        274
# 4         Icteria virens        391
# ...

# %%
BCR_unique = df['BCR'].unique()

# %%
bcr_to_state = pd.read_csv("/content/BCR_States_Coverage.csv")

# %%
bcr_to_state
# Out:
#                              BCR Name      State  Coverage
# 0                    Northern Rockies    Montana        60
# 1                    Northern Rockies    Wyoming        30
# 2                    Northern Rockies      Idaho        10
# 3   Southern Rockies/Colorado Plateau   Colorado        50
# 4   Southern Rockies/Colorado Plateau       Utah        30
# ..                                ...        ...       ...
# 69                  Oaks and Prairies   Oklahoma        40
# 70             Boreal Softwood Shield      Maine        20
# 71              Tamaulipan Brushlands      Texas       100
# 72               Gulf Coastal Prairie      Texas        60
# 73               Gulf Coastal Prairie  Louisiana        40
#
# [74 rows x 3 columns]

# %%
# Merge bird data with BCR-to-state data
merged_data = pd.merge(df, bcr_to_state, left_on="BCR", right_on="BCR Name")

# Calculate the BirdCount for each state based on coverage percentage
merged_data["NumBird"] = ((merged_data["BirdCount"] * merged_data["Coverage"]) / 100).round().astype(int)

# Drop unnecessary columns for a cleaner result
final_data = merged_data.drop(columns=["BCR Name", "Coverage", "BCR", "BirdCount"])

# %%
final_data
# Out:
#                   BirdName   BirdScientificName          State  NumBird
# 0               House Wren    Troglodytes aedon        Montana      546
# 1               House Wren    Troglodytes aedon        Wyoming      273
# 2               House Wren    Troglodytes aedon          Idaho       91
# 3           Warbling Vireo         Vireo gilvus       Colorado      602
# 4           Warbling Vireo         Vireo gilvus           Utah      361
# ...                    ...                  ...            ...      ...
# 1218     American Redstart  Setophaga ruticilla  New Hampshire      139
# 1219     American Redstart  Setophaga ruticilla        Vermont      139
# 1220      Bullock's Oriole    Icterus bullockii     California      576
# 1221  Brown-headed Cowbird       Molothrus ater         Nevada      434
# 1222  Brown-headed Cowbird       Molothrus ater           Utah      290
#
# [1223 rows x 4 columns]

# %%
final_data.to_csv("final_data.csv")
